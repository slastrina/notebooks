# %%
import pkgutil
for x in pkgutil.iter_modules():
    print(x)
# Out:
# ModuleInfo(module_finder=FileFinder('/Users/work/git/notebooks'), name='test', ispkg=False)
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7'), name='__future__', ispkg=False)
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7'), name='_bootlocale', ispkg=False)
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7'), name='_collections_abc', ispkg=False)
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7'), name='_compat_pickle', ispkg=False)
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7'), name='_compression', ispkg=False)
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7'), name='_dummy_thread', ispkg=False)
# ...

# %%
import importlib
for x in pkgutil.iter_modules():
    if 'auto' in x[1]:
        print(x)
        module = importlib.import_module(x[1])
# Out:
# ModuleInfo(module_finder=FileFinder('/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/extensions'), name='autoreload', ispkg=False)

# %%
print(dir(module))
# Out:
# ['AutoreloadMagics', 'Magics', 'ModuleReloader', 'StrongRef', 'UPDATE_RULES', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'func_attrs', 'gc', 'import_module', 'isinstance2', 'line_magic', 'load_ipython_extension', 'magics_class', 'os', 'reload', 'skip_doctest', 'source_from_cache', 'superreload', 'sys', 'traceback', 'types', 'update_class', 'update_function', 'update_generic', 'update_instances', 'update_property', 'weakref']
