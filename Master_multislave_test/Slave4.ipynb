# %%
import socket
import struct
import threading
import time
import sys

class listenThread (threading.Thread):
    def __init__(self, threadID, name, socket1, socket2, freq, mcast_grp1, mcast_port1, mcast_grp2, mcast_port2):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.sock1 = socket1 # Recieve
        self.sock2 = socket2 # Send
        self.freq = freq
        self.mcast_grp1 = mcast_grp1
        self.mcast_port1 = mcast_port1
        self.mcast_grp2 = mcast_grp2
        self.mcast_port2 = mcast_port2
        
    def run(self):
        print 'Thread {} "{}" Started'.format(self.threadID, self.name)
        while(1):
            time.sleep(self.freq)
            try:
                message, address = sock1.recvfrom(10240)
                if 'HeartBeat' in message:
                    # print message received
                    print '{}, {}, Message: "{}", Sender: {}'.format(time.ctime(time.time()), 'Receive', message, address)
                    
                    # send response
                    response = "Slave 4 Alive"
                    self.sock2.sendto(response, (self.mcast_grp2, self.mcast_port2))
                    print '{}, {}, Message: "{}"'.format(time.ctime(time.time()), 'Transmit', response)

            except:
                None
                #print "Unexpected error:", sys.exc_info()[0]

# Multicast Socket setup - Receive 
MCAST_GRP1 = '224.1.1.1'
MCAST_PORT1 = 5008
sock1 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
sock1.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
sock1.bind(('', MCAST_PORT1))  # use MCAST_GRP instead of '' to listen only
                             # to MCAST_GRP, not all groups on MCAST_PORT
mreq = struct.pack("4sl", socket.inet_aton(MCAST_GRP1), socket.INADDR_ANY)
sock1.setsockopt(socket.IPPROTO_IP, socket.IP_ADD_MEMBERSHIP, mreq)
sock1.setblocking(0)

# Multicast Socket setup - Send 
MCAST_GRP2 = '224.1.1.1' # despite binding to a group we end up accepting all multicast messages in the listen
MCAST_PORT2 = 5007
sock2 = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
sock2.setsockopt(socket.IPPROTO_IP, socket.IP_MULTICAST_TTL, 2)

# Create new threads
thread1 = listenThread(1, "Respond", sock1 ,sock2, 0.05, MCAST_GRP1, MCAST_PORT1, MCAST_GRP2, MCAST_PORT2)

# Start new Threads
thread1.start()

while(1):
    time.sleep(100)
# Out:
# Thread 1 "Respond" Started
# Thu Mar  9 22:04:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:04:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:04:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:05:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:05:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:06:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:06:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:07:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:07:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:08:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:08:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:09:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:09:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:10:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:10:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:11:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:11:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:12:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:12:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:13:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:13:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:14:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:14:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:15:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:15:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:16:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:16:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:17:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:17:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:18:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:18:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:19:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:19:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:20:58 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:20:58 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:03 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:03 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:08 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:08 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:13 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:13 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:18 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:18 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:23 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:23 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:28 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:28 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:33 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:33 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:38 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:38 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:43 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:43 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:48 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:48 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:53 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:53 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:21:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:21:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:22:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:22:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:23:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:23:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:24:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:24:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:25:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:25:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:26:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:26:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:27:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:27:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:28:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:28:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:29:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:29:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:14 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:19 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:19 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:24 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:24 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:29 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:29 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:34 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:34 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:39 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:39 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:44 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:44 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:49 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:49 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:54 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:54 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:30:59 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:30:59 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:31:04 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:31:04 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:31:09 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:31:09 2017, Transmit, Message: "Slave 4 Alive"
# Thu Mar  9 22:31:14 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Thu Mar  9 22:31:14 2017, Transmit, Message: "Slave 4 Alive"
# ...
# Fri Mar 10 00:04:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:04:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:04:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:05:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:05:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:06:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:06:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:07:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:07:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:08:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:08:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:09:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:09:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:10:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:10:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:11:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:11:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:01 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:06 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:06 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:11 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:11 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:16 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:16 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:21 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:21 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:26 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:26 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:31 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:31 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:36 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:36 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:41 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:41 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:46 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:46 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:51 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:51 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:12:56 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:12:56 2017, Transmit, Message: "Slave 4 Alive"
# Fri Mar 10 00:13:01 2017, Receive, Message: "HeartBeat", Sender: ('172.17.0.4', 46248)
# Fri Mar 10 00:13:01 2017, Transmit, Message: "Slave 4 Alive"
